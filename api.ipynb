# %% [markdown]
# #### Programas principales

# %%
import subprocess
import json

api_response = []
url = f'https://radiocut.fm/api/search/?type=cut&page=160494'
command = f'curl --request GET --url {url}'
result = subprocess.run(command, shell=True, capture_output=True, text=True, encoding='utf-8')
 
# Parse JSON response
json_data = json.loads(result.stdout)

# Extend the list with new results
api_response.extend(json_data['results'])

print(api_response)
# Out:
# [{'type': 'AudioCut', 'value': {'episode': None, 'description': '"Ojo Negro".\r\nLa primera entrevista de Alberto Fernández con un medio argentino y sus excusas.\r\nAlberto Fernández le dio su versión de los hechos al Cohete en una entrevista de una hora y cuarto en la mañana del viernes 9, con la condición de que no se publique antes de la otra entrevista que concedió, al diario español El País, que debería salir hoy. El ex Presidente alega que el hematoma no se debe a un golpe, sino a un tratamiento estético contra las arrugas. Los medios que siguen cada minuto del caso, recuerdan que también en 2021 Fernández primero negó que se hubiera producido el festejo en Olivos, luego puso en duda la autenticidad de la foto y terminó por incriminar a su pareja.\r\nEl editorial de Horacio Verbitsky del 11/08/2024 en El Cohete a la Luna.', 'title': 'Horacio Verbitsky - Ojo Negro - El Cohete a la Luna', 'radio_obj': {'slug': 'madres', 'name': 'AM 530 - Somos Radio', 'webpage': 'https://am530somosradio.com/', 'audio_url': 'https://ipanel.instream.audio:7000/stream', 'time_zone': 'America/Buenos_Aires', 'logo': 'https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/9d/af/9daffd2f-b4dc-4e1e-8242-ee98a4e66ae9.jpg', 'freq': '530.00', 'listen_mode': 'ondemand+live', 'band': 'AM', 'city': {'code': 'BUE', 'state': {'code': 'AR-C', 'country': {'code': 'AR', 'name': 'Argentina'}, 'name': 'Ciudad Autónoma de Buenos Aires'}, 'name': 'Ciudad de Buenos Aires'}, 'station_type': 'r', 'visibility': 'p', 'description_text': ''}, 'tags': [{'title': 'am 530', 'slug': 'am-530', 'id': 4395}, {'title': 'am 530 somos radio', 'slug': 'am-530-somos-radio', 'id': 177050}, {'title': 'el cohete a la luna', 'slug': 'cohete-a-luna_1', 'id': 262033}, {'title': 'horacio verbitsky', 'slug': 'horacio-verbitsky', 'id': 1184}, {'title': 'somos radio', 'slug': 'somos-radio', 'id': 171128}], 'show': 'cohete-a-luna', 'show_obj': {'slug': 'cohete-a-luna', 'name': 'El cohete a la Luna', 'description': '', 'radio': 'madres', 'twitter': '', 'facebook': '', 'webpage': '', 'logo': 'https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/9d/af/9daffd2f-b4dc-4e1e-8242-ee98a4e66ae9.jpg', 'radio_obj': {'slug': 'madres', 'name': 'AM 530 - Somos Radio', 'webpage': 'https://am530somosradio.com/', 'audio_url': 'https://ipanel.instream.audio:7000/stream', 'time_zone': 'America/Buenos_Aires', 'logo': 'https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/9d/af/9daffd2f-b4dc-4e1e-8242-ee98a4e66ae9.jpg', 'freq': '530.00', 'listen_mode': 'ondemand+live', 'band': 'AM', 'city': {'code': 'BUE', 'state': {'code': 'AR-C', 'country': {'code': 'AR', 'name': 'Argentina'}, 'name': 'Ciudad Autónoma de Buenos Aires'}, 'name': 'Ciudad de Buenos Aires'}, 'station_type': 'r', 'visibility': 'p', 'description_text': ''}, 'visibility': 'p'}, 'visibility': 'p', 'created': '2024-08-11T13:16:58.238Z', 'play_count': 1143, 'start': '2024-08-11T12:03:46+00:00', 'length': 4174, 'radio': 'madres', 'logo': 'https://imgsvr.radiocut.site/get/crop/center/200/200/cuts_logos/df/8f/df8f5f9b-4f36-4230-9ce4-53e1a9022292.png', 'owner': {'username': 'somosradio', 'id': 144544}, 'pk': 2078987, 'slug': 'horacio-verbitsky-ojo-negro-cohete-a-luna'}}, {'type': 'AudioCut', 'value': {'episode': None, 'description': 'Ricardo Aronskind hace un excelente análisis del momento político y del estado del campo popular y su conducción política', 'title': 'Reportaje a Ricardo Aronskind', 'radio_obj': {'slug': 'lared', 'name': 'La Red', 'webpage': 'https://www.lared.am/', 'audio_url': 'https://playerservices.streamtheworld.com/pls/LA_RED_AM910AAC.pls', 'time_zone': 'America/Buenos_Aires', 'logo': 'https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/11/07/11070b07-0331-4561-98c2-8c012f818238.png', 'freq': '910.00', 'listen_mode': 'ondemand+live', 'band': 'AM', 'city': {'code': 'BUE', 'state': {'code': 'AR-C', 'country': {'code': 'AR', 'name': 'Argentina'}, 'name': 'Ciudad Autónoma de Buenos Aires'}, 'name ...

# %%
import os
from dotenv import load_dotenv
import subprocess
import json
from collections import defaultdict
from datetime import datetime, timedelta

load_dotenv()

radiocut_api_key = os.getenv("RADIOCUT_API_KEY")

# Generar URLs para páginas 1 a 30
urls = [f'https://radiocut.fm/api/search/?type=cut&page={i}' for i in range(160492, 160493)]

headers = {
    "Authorization": f"Token {radiocut_api_key}",
    "accept": "application/json; charset=utf-8"
}

header_str = " ".join([f'--header \"{key}: {value}\"' for key, value in headers.items()])

resultados = []

for url in urls:
    command = f'curl --request GET --url {url} {header_str}'
    result = subprocess.run(command, shell=True, capture_output=True, text=True, encoding='utf-8')
    json_data = json.loads(result.stdout)
    resultados.extend(json_data['results'])  # Recopilar todos los resultados

print(resultados)
replicados = []
user_views = defaultdict(int)
user_recortes = defaultdict(int)
radio_recortes = defaultdict(int)
programa_recortes = defaultdict(int)

# Usar un set para identificar duplicados
seen = set()

duraciones = []

for item in resultados:
    titulo = item['value']['title']
    programa = item['value']['show']
    radio = item['value']['radio_obj']['name']
    empieza = item['value']['start']
    duracion = item['value']['length']
    descripcion = item['value']['description']
    usuario = item['value']['owner']['username']
    reproducciones = item['value']['play_count']
    etiquetas = item['value']['tags']
    slug = item['value']['slug']

    # Convertir 'empieza' a formato HH:MM:SS
    empieza_datetime = datetime.fromisoformat(empieza.replace('Z', '+00:00'))
    empieza_formatted = empieza_datetime.strftime('%H:%M:%S')

    # Convertir duración de segundos a formato HH:MM:SS
    def format_duration(seconds):
        return str(timedelta(seconds=seconds))

    duracion_formatted = format_duration(duracion)

    # Agregar la duración a la lista para cálculos estadísticos
    duraciones.append(duracion)

    # Generar URL con el título
    sanitized_title = slug
    generated_url = f"https://radiocut.fm/audiocut/{sanitized_title}"

    # Crear una clave única para el recorte
    unique_key = (titulo, programa, radio, empieza, duracion, descripcion, usuario, reproducciones, str(etiquetas))

    if unique_key not in seen:
        seen.add(unique_key)
        replicados.append({
            'titulo': titulo,
            'programa': programa,
            'radio': radio,
            'empieza': empieza_formatted,
            'duracion': duracion_formatted,
            'descripcion': descripcion,
            'usuario': usuario,
            'reproducciones': reproducciones,
            'etiquetas': etiquetas,
            'url': generated_url
        })

    # Agregar vistas y recortes por usuario
    user_views[usuario] += reproducciones
    user_recortes[usuario] += 1

    # Agregar recortes por radio y programa
    radio_recortes[radio] += 1
    programa_recortes[programa] += 1

# Ordenar por reproducciones para los 10 mejores usuarios
top_users_by_views = sorted(user_views.items(), key=lambda x: x[1], reverse=True)[:10]

# Ordenar por total de recortes para los 100 mejores usuarios
top_users_by_recortes = sorted(user_recortes.items(), key=lambda x: x[1], reverse=True)[:100]

# Obtener los 10 recortes con más vistas
sorted_replicados = sorted(replicados, key=lambda x: x['reproducciones'], reverse=True)
top_10_recortes = sorted_replicados[:10]

# Calcular estadísticas
duracion_max = max(duraciones) if duraciones else None
duracion_min = min(duraciones) if duraciones else None
promedio_duracion = sum(duraciones) / len(duraciones) if duraciones else None

duracion_max_formatted = format_duration(duracion_max) if duracion_max else None
duracion_min_formatted = format_duration(duracion_min) if duracion_min else None
promedio_duracion_formatted = format_duration(promedio_duracion) if promedio_duracion else None

# No es posible extraer años del campo 'empieza', por lo que este cálculo se omite

# Obtener las 5 radios y 5 programas con más recortes
top_5_radios = sorted(radio_recortes.items(), key=lambda x: x[1], reverse=True)[:5]
top_5_programas = sorted(programa_recortes.items(), key=lambda x: x[1], reverse=True)[:5]

# Imprimir resultados
print("Primeros 10 recortes con más vistas:")
print(json.dumps(top_10_recortes, indent=4, ensure_ascii=False))

print(f"\nCantidad de recortes evaluados: {len(replicados)}")
# No se imprime la cantidad de años evaluados

print(f"\nRecorte con más duración: {duracion_max_formatted}")
print(f"Promedio de duración de los recortes: {promedio_duracion_formatted}")
print(f"Recorte con menos duración: {duracion_min_formatted}")

print("\nTop 10 usuarios con más vistas:")
print(json.dumps(top_users_by_views, indent=4, ensure_ascii=False))

print("\nTop 100 usuarios con más recortes:")
print(json.dumps(top_users_by_recortes, indent=4, ensure_ascii=False))

print("\nTop 5 radios con más recortes:")
print(json.dumps(top_5_radios, indent=4, ensure_ascii=False))

print("\nTop 5 programas con más recortes:")
print(json.dumps(top_5_programas, indent=4, ensure_ascii=False))
# Out:
# [{'type': 'AudioCut', 'value': {'episode': None, 'description': '"Ojo Negro".\r\nLa primera entrevista de Alberto Fernández con un medio argentino y sus excusas.\r\nAlberto Fernández le dio su versión de los hechos al Cohete en una entrevista de una hora y cuarto en la mañana del viernes 9, con la condición de que no se publique antes de la otra entrevista que concedió, al diario español El País, que debería salir hoy. El ex Presidente alega que el hematoma no se debe a un golpe, sino a un tratamiento estético contra las arrugas. Los medios que siguen cada minuto del caso, recuerdan que también en 2021 Fernández primero negó que se hubiera producido el festejo en Olivos, luego puso en duda la autenticidad de la foto y terminó por incriminar a su pareja.\r\nEl editorial de Horacio Verbitsky del 11/08/2024 en El Cohete a la Luna.', 'title': 'Horacio Verbitsky - Ojo Negro - El Cohete a la Luna', 'radio_obj': {'slug': 'madres', 'name': 'AM 530 - Somos Radio', 'webpage': 'https://am530somosradio.com/', 'audio_url': 'https://ipanel.instream.audio:7000/stream', 'time_zone': 'America/Buenos_Aires', 'logo': 'https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/9d/af/9daffd2f-b4dc-4e1e-8242-ee98a4e66ae9.jpg', 'freq': '530.00', 'listen_mode': 'ondemand+live', 'band': 'AM', 'city': {'code': 'BUE', 'state': {'code': 'AR-C', 'country': {'code': 'AR', 'name': 'Argentina'}, 'name': 'Ciudad Autónoma de Buenos Aires'}, 'name': 'Ciudad de Buenos Aires'}, 'station_type': 'r', 'visibility': 'p', 'description_text': ''}, 'tags': [{'title': 'am 530', 'slug': 'am-530', 'id': 4395}, {'title': 'am 530 somos radio', 'slug': 'am-530-somos-radio', 'id': 177050}, {'title': 'el cohete a la luna', 'slug': 'cohete-a-luna_1', 'id': 262033}, {'title': 'horacio verbitsky', 'slug': 'horacio-verbitsky', 'id': 1184}, {'title': 'somos radio', 'slug': 'somos-radio', 'id': 171128}], 'show': 'cohete-a-luna', 'show_obj': {'slug': 'cohete-a-luna', 'name': 'El cohete a la Luna', 'description': '', 'radio': 'madres', 'twitter': '', 'facebook': '', 'webpage': '', 'logo': 'https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/9d/af/9daffd2f-b4dc-4e1e-8242-ee98a4e66ae9.jpg', 'radio_obj': {'slug': 'madres', 'name': 'AM 530 - Somos Radio', 'webpage': 'https://am530somosradio.com/', 'audio_url': 'https://ipanel.instream.audio:7000/stream', 'time_zone': 'America/Buenos_Aires', 'logo': 'https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/9d/af/9daffd2f-b4dc-4e1e-8242-ee98a4e66ae9.jpg', 'freq': '530.00', 'listen_mode': 'ondemand+live', 'band': 'AM', 'city': {'code': 'BUE', 'state': {'code': 'AR-C', 'country': {'code': 'AR', 'name': 'Argentina'}, 'name': 'Ciudad Autónoma de Buenos Aires'}, 'name': 'Ciudad de Buenos Aires'}, 'station_type': 'r', 'visibility': 'p', 'description_text': ''}, 'visibility': 'p'}, 'visibility': 'p', 'created': '2024-08-11T13:16:58.238Z', 'play_count': 1130, 'start': '2024-08-11T12:03:46+00:00', 'length': 4174, 'radio': 'madres', 'logo': 'https://imgsvr.radiocut.site/get/crop/center/200/200/cuts_logos/df/8f/df8f5f9b-4f36-4230-9ce4-53e1a9022292.png', 'owner': {'username': 'somosradio', 'id': 144544}, 'pk': 2078987, 'slug': 'horacio-verbitsky-ojo-negro-cohete-a-luna'}}, {'type': 'AudioCut', 'value': {'episode': None, 'description': 'Ricardo Aronskind hace un excelente análisis del momento político y del estado del campo popular y su conducción política', 'title': 'Reportaje a Ricardo Aronskind', 'radio_obj': {'slug': 'lared', 'name': 'La Red', 'webpage': 'https://www.lared.am/', 'audio_url': 'https://playerservices.streamtheworld.com/pls/LA_RED_AM910AAC.pls', 'time_zone': 'America/Buenos_Aires', 'logo': 'https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/11/07/11070b07-0331-4561-98c2-8c012f818238.png', 'freq': '910.00', 'listen_mode': 'ondemand+live', 'band': 'AM', 'city': {'code': 'BUE', 'state': {'code': 'AR-C', 'country': {'code': 'AR', 'name': 'Argentina'}, 'name': 'Ciudad Autónoma de Buenos Aires'}, 'name ...
# Primeros 10 recortes con más vistas:
# [
#     {
#         "titulo": "El pase entre Víctor Hugo y Cynthia García",
#         "programa": "te-quiero-a-las-10",
#         "radio": "AM 750",
#         "empieza": "11:57:11",
#         "duracion": "0:08:50",
#         "descripcion": "Volvé a escuchar el pase de las 9:00 por la 750. ",
#         "usuario": "RadioAM750",
#         "reproducciones": 5283,
#         "etiquetas": [],
#         "url": "https://radiocut.fm/audiocut/pase-entre-victor-hugo-y-cynthia-garcia"
#     },
#     {
#         "titulo": "Yo ya sé - ¿Adelanto de La Lógica del escorpión? ",
#         "programa": "todo-este-ruido-1",
#         "radio": " Radio Provincia Am1270",
#         "empieza": "15:55:25",
#         "duracion": "0:02:34",
#         "descripcion": "Yo ya sé - Adelanto de La Lógica del escorpión ",
#         "usuario": "hergarcia78",
#         "reproducciones": 2575,
#         "etiquetas": [
#             {
#                 "title": "charly garcía",
#                 "slug": "charly-garcia",
#                 "id": 1450
#             },
#             {
#                 "title": "la lógica del escorpión",
#                 "slug": "logica-del-escorpion",
#                 "id": 448151
#             }
#         ],
#         "url": "https://radiocut.fm/audiocut/yo-ya-se-adelanto-logica-del-escorpion"
#     },
#     {
#         "titulo": "Horacio Verbitsky - Ojo Negro - El Cohete a la Luna",
#         "programa": "cohete-a-luna",
#         "radio": "AM 530 - Somos Radio",
#         "empieza": "12:03:46",
#         "duracion": "1:09:34",
#         "descripcion": "\"Ojo Negro\".\r\nLa primera entrevista de Alberto Fernández con un medio argentino y sus excusas.\r\nAlberto Fernández le dio su versión de los hechos al Cohete en una entrevista de una hora y cuarto en la mañana del viernes 9, con la condición de que no se publique antes de la otra entrevista que concedió, al diario español El País, que debería salir hoy. El ex Presidente alega que el hematoma no se debe a un golpe, sino a un tratamiento estético contra las arrugas. Los medios que siguen cada minuto del caso, recuerdan que también en 2021 Fernández primero negó que se hubiera producido el festejo en Olivos, luego puso en duda la autenticidad de la foto y terminó por incriminar a su pareja.\r\nEl editorial de Horacio Verbitsky del 11/08/2024 en El Cohete a la Luna.",
#         "usuario": "somosradio",
#         "reproducciones": 1130,
#         "etiquetas": [
#             {
#                 "title": "am 530",
#                 "slug": "am-530",
#                 "id": 4395
#             },
#             {
#                 "title": "am 530 somos radio",
#                 "slug": "am-530-somos-radio",
#                 "id": 177050
#             },
#             {
#                 "title": "el cohete a la luna",
#                 "slug": "cohete-a-luna_1",
#                 "id": 262033
#             },
#             {
#                 "title": "horacio verbitsky",
#                 "slug": "horacio-verbitsky",
#                 "id": 1184
#             },
#             {
#                 "title": "somos radio",
#                 "slug": "somos-radio",
#                 "id": 171128
#             }
#         ],
#         "url": "https://radiocut.fm/audiocut/horacio-verbitsky-ojo-negro-cohete-a-luna"
#     },
#     {
#         "titulo": "Editorial Eduardo Aliverti 10/08/2024",
#         "programa": "marca-de-radio",
#         "radio": "La Red",
#         "empieza": "13:07:23",
#         "duracion": "0:16:57",
#         "descripcion": "Argentina en la semana \"Alberto Fernández\"",
#         "usuario": "sodamanatico",
#         "reproducciones": 1002,
#         "etiquetas": [],
#         "url": "https://radiocut.fm/audiocut/editorial-eduardo-aliverti-10-08-2024"
#     },
#     {
#         "titulo": "Reportaje a Ricardo Aronskind",
#         "programa": "marca-de-radio",
#         "radio": "La Red",
#         "empieza": "14:04:51",
#         "duracion": "0:35:25",
#         "descripcion": "Ricardo Aronskind hace un excelente análisis del momento político y del estado del campo popular y su conducción política",
#         "usuario": "aliciafernandez",
#         "reproducciones": 777,
#         "etiquetas": [],
#         "url": "https://radiocut.fm/audiocut/reportaje-a-ricardo-aronskind-2"
#     },
#     {
#         "titulo": "Editorial Eduardo Aliverti - Marca de Radio - 10/08/2024",
#         "programa": "marca-de-radio",
#         "radio": "La Red",
#         "empieza": "13:05:37",
#         "duracion": "0:18:40",
#         "descripcion": "Es el triunfo del antipolítica, el dedo que acusa solo a un lado, el verso de la honestidad en manos de los corruptos más evidentes la transitoria. Confianza o resignación popular, depositada en Los Auténticos Verdugos populares, la Argentina sin embargo tiene mucha experiencia en la resistencia en los cuerpos más dinámicos de su sociedad. Eso sí, esta vez no se trata solo de la resistencia, construir otra cosa es más urgente que nunca!\r\n",
#         "usuario": "skay",
#         "reproducciones": 440,
#         "etiquetas": [
#             {
#                 "title": "editorial",
#                 "slug": "editorial",
#                 "id": 283
#             },
#             {
#                 "title": "editorial de aliverti",
#                 "slug": "editorial-aliverti_1",
#                 "id": 237389
#             },
#             {
#                 "title": "eduardo aliverti",
#                 "slug": "eduardo-aliverti",
#                 "id": 900
#             },
#             {
#                 "title": "marca de radio",
#                 "slug": "marca-radio",
#                 "id": 237387
#             }
#         ],
#         "url": "https://radiocut.fm/audiocut/editorial-eduardo-aliverti-marca-radio-10-08-2024"
#     },
#     {
#         "titulo": " Marcelo Figueras - La Comunidad (Des)Organizada - El Cohete a la Luna",
#         "programa": "cohete-a-luna",
#         "radio": "AM 530 - Somos Radio",
#         "empieza": "13:54:12",
#         "duracion": "0:28:53",
#         "descripcion": "\"La Comunidad (Des)Organizada\".\r\nUna pequeña obra maestra de los '90 rescata el valor de reconstruirse a partir de la decencia.\r\nLa Columna de Marcelo Figueras del 11/08/2024 en El Cohete a la Luna.",
#         "usuario": "somosradio",
#         "reproducciones": 174,
#         "etiquetas": [
#             {
#                 "title": "am 530",
#                 "slug": "am-530",
#                 "id": 4395
#             },
#             {
#                 "title": "am 530 somos radio",
#                 "slug": "am-530-somos-radio",
#                 "id": 177050
#             },
#             {
#                 "title": "el cohete a la luna",
#                 "slug": "cohete-a-luna_1",
#                 "id": 262033
#             },
#             {
#                 "title": "horacio verbitsky",
#                 "slug": "horacio-verbitsky",
#                 "id": 1184
#             },
#             {
#                 "title": "marcelo figueras",
#                 "slug": "marcelo-figueras",
#                 "id": 45024
#             },
#             {
#                 "title": "somos radio",
#                 "slug": "somos-radio",
#                 "id": 171128
#             }
#         ],
#         "url": "https://radiocut.fm/audiocut/marcelo-figueras-comunidad-des-organizada-cohete-a-luna"
#     },
#     {
#         "titulo": "El Cohete a la Luna - Dora Barrancos - 11/08/2024",
#         "programa": "cohete-a-luna",
#         "radio": "AM 530 - Somos Radio",
#         "empieza": "12:43:56",
#         "duracion": "0:06:19",
#         "descripcion": "Lo que trascendió sobre lo expresado por Dora Barrancos en un chat, sobre el caso Fernández-Yáñez.",
#         "usuario": "yannoulas",
#         "reproducciones": 173,
#         "etiquetas": [
#             {
#                 "title": "el cohete a la luna - dora barrancos - 11/08/2024",
#                 "slug": "cohete-a-luna-dora-barrancos-11-08-2024",
#                 "id": 610647
#             }
#         ],
#         "url": "https://radiocut.fm/audiocut/cohete-a-luna-dora-barrancos-11-08-2024"
#     },
#     {
#         "titulo": "Entrevista completa a Mayra Mendoza en FM Millenium",
#         "programa": "la-confesion-de-parte",
#         "radio": "Milenium",
#         "empieza": "15:06:30",
#         "duracion": "0:01:58",
#         "descripcion": "Entrevista a Mayra Mendoza por Romina Manguel.",
#         "usuario": "LaCampora",
#         "reproducciones": 99,
#         "etiquetas": [],
#         "url": "https://radiocut.fm/audiocut/entrevista-completa-a-mayra-mendoza-en-fm-millenium"
#     },
#     {
#         "titulo": "M SOSA DE CEDEMS: DOCENTES DE JUJUY CON PÉRDIDA SALARIAL Y PAROS.",
#         "programa": "voces-maestras",
#         "radio": "Radio Gráfica - Recuperando el aire",
#         "empieza": "11:31:23",
#         "duracion": "0:16:40",
#         "descripcion": "M. SOSA SEC GRAL DE CEDEMS : LOS DOC DE JUJUY  CON SALARIOS MENORES A 420 MIL CUANDO PARA NO ESTAR EN LINEA DE POBREZA SEGUN ATE INDEC DEBE ESTAR SOBRE 900 MIL , HABLA DE UNA PERDIDA MAYOR DE 30% , LA FALTA DEL FONID QUITADO POR MILEY, RESTRICCION DE ABONOS .DONDE LOS DOCENTES VIAJAN A PUEBLOS Y ESTAN MUY CAROS LOS PASAJES.LUGARES SIN DOCENTES, CIERRE DE DIVISIONES.EL RIESGO POR LA PARALIZACION DE aRREGLOS DE RUTAS DECIDIDO POR MILEI. Descuentos por dia de paro.no hay paritarias.no hay negociacion por parte del gob .imponen.Habla DE UNA NUEVA TASA GIRSU QUE COBRAN AL PUEBLO , LA EMPRESA RECICLADORA PERTENECE AL GOB. .TAMBIEN HABLA DE EL MAL MANEJO DE LA OBRA SOCIAL .juntan firmas contra el RIGI.",
#         "usuario": "vocesmaestras19",
#         "reproducciones": 70,
#         "etiquetas": [
#             {
#                 "title": "docentes de jujuy con pérdida salarial y paros",
#                 "slug": "docentes-jujuy-con-perdida-salarial-y-paros",
#                 "id": 610633
#             },
#             {
#                 "title": "mercedes sosa de cedems",
#                 "slug": "mercedes-sosa-cedems",
#                 "id": 610632
#             }
#         ],
#         "url": "https://radiocut.fm/audiocut/m-sosa-cedems-docentes-jujuy-con-perdida-salarial-y-paros"
#     }
# ]
#
# Cantidad de recortes evaluados: 12
#
# Recorte con más duración: 1:09:34
# Promedio de duración de los recortes: 0:21:03.250000
# Recorte con menos duración: 0:01:58
#
# Top 10 usuarios con más vistas:
# [
#     [
#         "RadioAM750",
#         5283
#     ],
#     [
#         "hergarcia78",
#         2575
#     ],
#     [
#         "somosradio",
#         1366
#     ],
#     [
#         "sodamanatico",
#         1002
#     ],
#     [
#         "aliciafernandez",
#         777
#     ],
#     [
#         "skay",
#         440
#     ],
#     [
#         "yannoulas",
#         173
#     ],
#     [
#         "LaCampora",
#         99
#     ],
#     [
#         "vocesmaestras19",
#         70
#     ],
#     [
#         "SantiAragn2",
#         56
#     ]
# ]
#
# Top 100 usuarios con más recortes:
# [
#     [
#         "somosradio",
#         3
#     ],
#     [
#         "aliciafernandez",
#         1
#     ],
#     [
#         "skay",
#         1
#     ],
#     [
#         "RadioAM750",
#         1
#     ],
#     [
#         "hergarcia78",
#         1
#     ],
#     [
#         "yannoulas",
#         1
#     ],
#     [
#         "sodamanatico",
#         1
#     ],
#     [
#         "LaCampora",
#         1
#     ],
#     [
#         "SantiAragn2",
#         1
#     ],
#     [
#         "vocesmaestras19",
#         1
#     ]
# ]
#
# Top 5 radios con más recortes:
# [
#     [
#         "AM 530 - Somos Radio",
#         4
#     ],
#     [
#         "La Red",
#         3
#     ],
#     [
#         "AM 750",
#         1
#     ],
#     [
#         " Radio Provincia Am1270",
#         1
#     ],
#     [
#         "Milenium",
#         1
#     ]
# ]
#
# Top 5 programas con más recortes:
# [
#     [
#         "cohete-a-luna",
#         4
#     ],
#     [
#         "marca-de-radio",
#         3
#     ],
#     [
#         "te-quiero-a-las-10",
#         1
#     ],
#     [
#         "todo-este-ruido-1",
#         1
#     ],
#     [
#         "la-confesion-de-parte",
#         1
#     ]
# ]

# %%
import os
from dotenv import load_dotenv
from mistralai.client import MistralClient
from mistralai.models.chat_completion import ChatMessage

load_dotenv()

api_key = os.getenv("MISTRAL_API_KEY")
if not api_key:
    raise ValueError("Error con las variables de entorno.")

model = "mistral-large-latest"

client = MistralClient(api_key=api_key)

# %%
print(resultados)
# Out:
# [{'type': 'AudioCut', 'value': {'episode': None, 'description': 'Argentina en la semana "Alberto Fernández"', 'title': 'Editorial Eduardo Aliverti 10/08/2024', 'radio_obj': {'slug': 'lared', 'name': 'La Red', 'webpage': 'https://www.lared.am/', 'audio_url': 'https://playerservices.streamtheworld.com/pls/LA_RED_AM910AAC.pls', 'time_zone': 'America/Buenos_Aires', 'logo': 'https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/11/07/11070b07-0331-4561-98c2-8c012f818238.png', 'freq': '910.00', 'listen_mode': 'ondemand+live', 'band': 'AM', 'city': {'code': 'BUE', 'state': {'code': 'AR-C', 'country': {'code': 'AR', 'name': 'Argentina'}, 'name': 'Ciudad Autónoma de Buenos Aires'}, 'name': 'Ciudad de Buenos Aires'}, 'station_type': 'r', 'visibility': 'p', 'description_text': ''}, 'tags': [], 'show': 'marca-de-radio', 'show_obj': {'slug': 'marca-de-radio', 'name': 'Marca de Radio', 'description': 'Conduce:Eduardo Aliverti ', 'radio': 'lared', 'twitter': '', 'facebook': 'https://www.facebook.com/pages/M', 'webpage': 'http://www.marcaderadio.com.ar/', 'logo': 'https://imgsvr.radiocut.site/get/crop/center/200/200/shows_logos/89/6e/896e547b-6e16-4658-b21e-9fe521ff1e8d.jpg', 'radio_obj': {'slug': 'lared', 'name': 'La Red', 'webpage': 'https://www.lared.am/', 'audio_url': 'https://playerservices.streamtheworld.com/pls/LA_RED_AM910AAC.pls', 'time_zone': 'America/Buenos_Aires', 'logo': 'https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/11/07/11070b07-0331-4561-98c2-8c012f818238.png', 'freq': '910.00', 'listen_mode': 'ondemand+live', 'band': 'AM', 'city': {'code': 'BUE', 'state': {'code': 'AR-C', 'country': {'code': 'AR', 'name': 'Argentina'}, 'name': 'Ciudad Autónoma de Buenos Aires'}, 'name': 'Ciudad de Buenos Aires'}, 'station_type': 'r', 'visibility': 'p', 'description_text': ''}, 'visibility': 'p'}, 'visibility': 'p', 'created': '2024-08-10T14:02:56.066Z', 'play_count': 871, 'start': '2024-08-10T13:07:23+00:00', 'length': 1017, 'radio': 'lared', 'logo': 'https://imgsvr.radiocut.site/get/crop/center/200/200/shows_logos/89/6e/896e547b-6e16-4658-b21e-9fe521ff1e8d.jpg', 'owner': {'username': 'sodamanatico', 'id': 12122}, 'pk': 2078859, 'slug': 'editorial-eduardo-aliverti-10-08-2024'}}, {'type': 'AudioCut', 'value': {'episode': None, 'description': 'Ricardo Aronskind hace un excelente análisis del momento político y del estado del campo popular y su conducción política', 'title': 'Reportaje a Ricardo Aronskind', 'radio_obj': {'slug': 'lared', 'name': 'La Red', 'webpage': 'https://www.lared.am/', 'audio_url': 'https://playerservices.streamtheworld.com/pls/LA_RED_AM910AAC.pls', 'time_zone': 'America/Buenos_Aires', 'logo': 'https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/11/07/11070b07-0331-4561-98c2-8c012f818238.png', 'freq': '910.00', 'listen_mode': 'ondemand+live', 'band': 'AM', 'city': {'code': 'BUE', 'state': {'code': 'AR-C', 'country': {'code': 'AR', 'name': 'Argentina'}, 'name': 'Ciudad Autónoma de Buenos Aires'}, 'name': 'Ciudad de Buenos Aires'}, 'station_type': 'r', 'visibility': 'p', 'description_text': ''}, 'tags': [], 'show': 'marca-de-radio', 'show_obj': {'slug': 'marca-de-radio', 'name': 'Marca de Radio', 'description': 'Conduce:Eduardo Aliverti ', 'radio': 'lared', 'twitter': '', 'facebook': 'https://www.facebook.com/pages/M', 'webpage': 'http://www.marcaderadio.com.ar/', 'logo': 'https://imgsvr.radiocut.site/get/crop/center/200/200/shows_logos/89/6e/896e547b-6e16-4658-b21e-9fe521ff1e8d.jpg', 'radio_obj': {'slug': 'lared', 'name': 'La Red', 'webpage': 'https://www.lared.am/', 'audio_url': 'https://playerservices.streamtheworld.com/pls/LA_RED_AM910AAC.pls', 'time_zone': 'America/Buenos_Aires', 'logo': 'https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/11/07/11070b07-0331-4561-98c2-8c012f818238.png', 'freq': '910.00', 'listen_mode': 'ondemand+live', 'band': 'AM', 'city': {'code': 'BUE', 'state': {'code': 'AR-C', 'country': {'code': 'AR', 'name': 'Argentina'}, 'name': 'Ciudad Au ...

# %%
def flatDictToTxt(dict_list, file_path):
    with open(file_path, 'w', encoding='utf-8') as file:
        for dictionary in dict_list:
            for key, value in dictionary.items():
                # Escribe cada llave y valor en el archivo
                file.write(f"{key}: {value}\n")  # Cambio a '\n' para nueva línea
            file.write("\n")  # Añade una línea en blanco entre diccionarios

# Ejemplo de uso

file_path = 'output.txt'

# Escritura del archivo
flatDictToTxt(resultados, file_path)

# %%
from langchain.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_mistralai import MistralAIEmbeddings
import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("MISTRAL_API_KEY")
if not api_key:
    raise ValueError("Error con las variables de entorno.")

os.environ['HF_TOKEN'] = os.getenv('HF_TOKEN')

mistral = MistralAIEmbeddings(
    model="mistral-embed",
    api_key=api_key
)

# Cargar el archivo de texto
loader = TextLoader("output.txt", encoding="utf-8")
documents = loader.load()

# Dividir el texto en chunks
text_splitter = CharacterTextSplitter(chunk_size=1024, chunk_overlap=128)  # Redujimos el chunk_size
texts = text_splitter.split_documents(documents)

# Obtener embeddings y manejar errores
try:
    embeddings = mistral.embed_documents([text.page_content for text in texts])
    
    # Verificar si la respuesta contiene la clave 'data'
    if 'data' not in embeddings:
        raise ValueError(f"Formato de respuesta inesperado: {embeddings}")

    # Crear vectorstore usando FAISS
    vectorstore = FAISS.from_documents(texts, mistral)

except Exception as e:
    print(f"Error al obtener embeddings o al crear vectorstore: {e}")
# Out:
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# Created a chunk of size 2568, which is longer than the specified 1024
# Created a chunk of size 2221, which is longer than the specified 1024
# Created a chunk of size 2290, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2250, which is longer than the specified 1024
# Created a chunk of size 2916, which is longer than the specified 1024
# Created a chunk of size 2398, which is longer than the specified 1024
# Created a chunk of size 2273, which is longer than the specified 1024
# Created a chunk of size 2228, which is longer than the specified 1024
# Created a chunk of size 2631, which is longer than the specified 1024
# Created a chunk of size 2601, which is longer than the specified 1024
# Created a chunk of size 1544, which is longer than the specified 1024
# An error occurred with MistralAI: 'data'
# Error al obtener embeddings o al crear vectorstore: 'data'

# %%
from langchain_mistralai.chat_models import ChatMistralAI
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain

# Define una interfaz retriever (ahí está el context)
retriever = vectorstore.as_retriever()
# Instancia el Chat
model = ChatMistralAI(api_key=api_key)
# Define prompt template
prompt = ChatPromptTemplate.from_template("""Responde la siguiente pregunta basándote únicamente en el contexto provisto:

<context>
{context}
</context>

Question: {input}""")

# Crea una cadena de retrieval para responder a la pregunta
document_chain = create_stuff_documents_chain(model, prompt)
retrieval_chain = create_retrieval_chain(retriever, document_chain)
response = retrieval_chain.invoke({"input": "¿Cuáles son los veinte recortes con más reproducciones?"})
print(response["answer"])
# Out:
# No es posible proporcionar los veinte recortes con más reproducciones, ya que el contexto solo proporciona detalles de ocho recortes. Sin embargo, puedo decir cuáles son los ocho recortes del contexto, ordenados de mayor a menor número de reproducciones.
#
# 1. Turista denunció que la Policía Caminera de Córdoba lo quiso coimear y amenazó con matar a su hijo - 207 reproducciones
# 2. PROGRAMA COMPLETO DEL 10-08-24 - 56 reproducciones
# 3. Editorial Eduardo Aliverti 10/08/2024 - 871 reproducciones
# 4. Reportaje a Ricardo Aronskind - 446 reproducciones
# 5. Andrés Larroque en Radio 10 - 98 reproducciones
# 6. Luis Mario Vitette con Víctor Hugo Morales - 695 reproducciones
# 7. Yo ya sé - Adelanto de La Lógica del escorpión - 2457 reproducciones
# 8. El pase entre Víctor Hugo y Cynthia García - 4944 reproducciones

# %% [markdown]
# #### Búsqueda de un término en todos los tipos de objetos, radios, programas y recortes

# %%
url = 'https://radiocut.fm/api/search/?type=all&search_term=avion'

command = f'curl --request GET --url {url} {header_str}'

result = subprocess.run(command, shell=True, capture_output=True, text=True, encoding='utf-8')

json_data = json.loads(result.stdout)

print(json.dumps(json_data, indent=4))
# Out:
# {
#     "count": 2430558,
#     "next": "https://radiocut.fm/api/search/?page=2&type=all",
#     "previous": null,
#     "results": [
#         {
#             "type": "RadioStation",
#             "value": {
#                 "slug": "city",
#                 "name": "Con Vos",
#                 "webpage": "http://www.radioconvos.com.ar/",
#                 "audio_url": "https://server1.stweb.tv/rcvos/live/playlist.m3u8",
#                 "time_zone": "America/Buenos_Aires",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/77/19/7719d9e2-18d4-4b47-8871-f597b704f75d.jpg",
#                 "freq": "89.90",
#                 "listen_mode": "ondemand+live",
#                 "band": "FM",
#                 "city": {
#                     "code": "BUE",
#                     "state": {
#                         "code": "AR-C",
#                         "country": {
#                             "code": "AR",
#                             "name": "Argentina"
#                         },
#                         "name": "Ciudad Aut\u00f3noma de Buenos Aires"
#                     },
#                     "name": "Ciudad de Buenos Aires"
#                 },
#                 "station_type": "r",
#                 "visibility": "p",
#                 "description_text": ""
#             }
#         },
#         {
#             "type": "RadioStation",
#             "value": {
#                 "slug": "madres",
#                 "name": "AM 530 - Somos Radio",
#                 "webpage": "https://am530somosradio.com/",
#                 "audio_url": "https://ipanel.instream.audio:7000/stream",
#                 "time_zone": "America/Buenos_Aires",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/9d/af/9daffd2f-b4dc-4e1e-8242-ee98a4e66ae9.jpg",
#                 "freq": "530.00",
#                 "listen_mode": "ondemand+live",
#                 "band": "AM",
#                 "city": {
#                     "code": "BUE",
#                     "state": {
#                         "code": "AR-C",
#                         "country": {
#                             "code": "AR",
#                             "name": "Argentina"
#                         },
#                         "name": "Ciudad Aut\u00f3noma de Buenos Aires"
#                     },
#                     "name": "Ciudad de Buenos Aires"
#                 },
#                 "station_type": "r",
#                 "visibility": "p",
#                 "description_text": ""
#             }
#         },
#         {
#             "type": "RadioStation",
#             "value": {
#                 "slug": "futurock",
#                 "name": "Futurock FM",
#                 "webpage": "http://www.futurock.fm/",
#                 "audio_url": "https://mdstrm.com/audio/5d9d019112cbbb45d6a50960/live.m3u8",
#                 "time_zone": "America/Buenos_Aires",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/03_pWQ5vi8.jpg",
#                 "freq": null,
#                 "listen_mode": "ondemand+live",
#                 "band": "IN",
#                 "city": {
#                     "code": "BUE",
#                     "state": {
#                         "code": "AR-C",
#                         "country": {
#                             "code": "AR",
#                             "name": "Argentina"
#                         },
#                         "name": "Ciudad Aut\u00f3noma de Buenos Aires"
#                     },
#                     "name": "Ciudad de Buenos Aires"
#                 },
#                 "station_type": "r",
#                 "visibility": "p",
#                 "description_text": ""
#             }
#         },
#         {
#             "type": "RadioStation",
#             "value": {
#                 "slug": "pop",
#                 "name": "Pop 101.5",
#                 "webpage": "https://www.radiopop.fm/",
#                 "audio_url": "https://popradio.stweb.tv/popradio/live/playlist.m3u8",
#                 "time_zone": "America/Buenos_Aires",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/29/cf/29cf86b4-16ca-4309-bd50-e084f0c0dc1b.jpg",
#                 "freq": "101.50",
#                 "listen_mode": "ondemand+live",
#                 "band": "FM",
#                 "city": {
#                     "code": "BUE",
#                     "state": {
#                         "code": "AR-C",
#                         "country": {
#                             "code": "AR",
#                             "name": "Argentina"
#                         },
#                         "name": "Ciudad Aut\u00f3noma de Buenos Aires"
#                     },
#                     "name": "Ciudad de Buenos Aires"
#                 },
#                 "station_type": "r",
#                 "visibility": "p",
#                 "description_text": ""
#             }
#         },
#         {
#             "type": "RadioStation",
#             "value": {
#                 "slug": "am750",
#                 "name": "AM 750",
#                 "webpage": "http://radioam750.com.ar/",
#                 "audio_url": "https://playerservices.streamtheworld.com/pls/AM750.pls",
#                 "time_zone": "America/Buenos_Aires",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/1a/1c/1a1c34bb-fa46-42f4-b6e3-3018d647b6f8.png",
#                 "freq": "750.00",
#                 "listen_mode": "ondemand+live",
#                 "band": "AM",
#                 "city": {
#                     "code": "BUE",
#                     "state": {
#                         "code": "AR-C",
#                         "country": {
#                             "code": "AR",
#                             "name": "Argentina"
#                         },
#                         "name": "Ciudad Aut\u00f3noma de Buenos Aires"
#                     },
#                     "name": "Ciudad de Buenos Aires"
#                 },
#                 "station_type": "r",
#                 "visibility": "p",
#                 "description_text": ""
#             }
#         },
#         {
#             "type": "RadioStation",
#             "value": {
#                 "slug": "lared",
#                 "name": "La Red",
#                 "webpage": "https://www.lared.am/",
#                 "audio_url": "https://playerservices.streamtheworld.com/pls/LA_RED_AM910AAC.pls",
#                 "time_zone": "America/Buenos_Aires",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/11/07/11070b07-0331-4561-98c2-8c012f818238.png",
#                 "freq": "910.00",
#                 "listen_mode": "ondemand+live",
#                 "band": "AM",
#                 "city": {
#                     "code": "BUE",
#                     "state": {
#                         "code": "AR-C",
#                         "country": {
#                             "code": "AR",
#                             "name": "Argentina"
#                         },
#                         "name": "Ciudad Aut\u00f3noma de Buenos Aires"
#                     },
#                     "name": "Ciudad de Buenos Aires"
#                 },
#                 "station_type": "r",
#                 "visibility": "p",
#                 "description_text": ""
#             }
#         },
#         {
#             "type": "RadioStation",
#             "value": {
#                 "slug": "radio10",
#                 "name": "Radio 10",
#                 "webpage": "http://www.radio10.com.ar/",
#                 "audio_url": "https://radio10.stweb.tv/radio10/live/playlist.m3u8",
#                 "time_zone": "America/Buenos_Aires",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/4a/57/4a57e7f4-c34e-4cc2-bd2c-b291bb105231.jpg",
#                 "freq": "710.00",
#                 "listen_mode": "ondemand+live",
#                 "band": "AM",
#                 "city": {
#                     "code": "BUE",
#                     "state": {
#                         "code": "AR-C",
#                         "country": {
#                             "code": "AR",
#                             "name": "Argentina"
#                         },
#                         "name": "Ciudad Aut\u00f3noma de Buenos Aires"
#                     },
#                     "name": "Ciudad de Buenos Aires"
#                 },
#                 "station_type": "r",
#                 "visibility": "p",
#                 "description_text": ""
#             }
#         },
#         {
#             "type": "RadioStation",
#             "value": {
#                 "slug": "el-destape",
#                 "name": "Re",
#                 "webpage": "https://www.eldestaperadio.com/",
#                 "audio_url": "https://ipanel.instream.audio:7014/stream",
#                 "time_zone": "America/Buenos_Aires",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/6e/7f/6e7f60b8-ab9c-4c89-8826-b23e00dc95aa.png",
#                 "freq": "107.30",
#                 "listen_mode": "ondemand+live",
#                 "band": "FM",
#                 "city": {
#                     "code": "BUE",
#                     "state": {
#                         "code": "AR-C",
#                         "country": {
#                             "code": "AR",
#                             "name": "Argentina"
#                         },
#                         "name": "Ciudad Aut\u00f3noma de Buenos Aires"
#                     },
#                     "name": "Ciudad de Buenos Aires"
#                 },
#                 "station_type": "r",
#                 "visibility": "p",
#                 "description_text": ""
#             }
#         },
#         {
#             "type": "RadioStation",
#             "value": {
#                 "slug": "rivadavia",
#                 "name": "Rivadavia",
#                 "webpage": "http://www.rivadavia.com.ar/",
#                 "audio_url": "https://playerservices.streamtheworld.com/pls/RIVADAVIAAAC.pls",
#                 "time_zone": "America/Buenos_Aires",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/77/93/7793b356-44fe-4e77-a360-8b95dc9fc943.jpg",
#                 "freq": "630.00",
#                 "listen_mode": "ondemand+live",
#                 "band": "AM",
#                 "city": {
#                     "code": "BUE",
#                     "state": {
#                         "code": "AR-C",
#                         "country": {
#                             "code": "AR",
#                             "name": "Argentina"
#                         },
#                         "name": "Ciudad Aut\u00f3noma de Buenos Aires"
#                     },
#                     "name": "Ciudad de Buenos Aires"
#                 },
#                 "station_type": "r",
#                 "visibility": "p",
#                 "description_text": ""
#             }
#         },
#         {
#             "type": "RadioStation",
#             "value": {
#                 "slug": "urbana-play",
#                 "name": "Urbana Play 104.3 FM",
#                 "webpage": "http://urbanaplayfm.com/",
#                 "audio_url": "https://vmf.edge-apps.net/playlist/urbana.m3u8/play.m3u8",
#                 "time_zone": "America/Buenos_Aires",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/16/16/16168f46-4590-492e-9cd3-e13e75b345c7.jpg",
#                 "freq": "104.30",
#                 "listen_mode": "ondemand+live",
#                 "band": "FM",
#                 "city": {
#                     "code": "BUE",
#                     "state": {
#                         "code": "AR-C",
#                         "country": {
#                             "code": "AR",
#                             "name": "Argentina"
#                         },
#                         "name": "Ciudad Aut\u00f3noma de Buenos Aires"
#                     },
#                     "name": "Ciudad de Buenos Aires"
#                 },
#                 "station_type": "r",
#                 "visibility": "p",
#                 "description_text": "Urbana Play 104.3 FM"
#             }
#         },
#         {
#             "type": "RadioStation",
#             "value": {
#                 "slug": "destape-mundo",
#                 "name": "El Destape Mundo",
#                 "webpage": "https://www.eldestapeweb.com/",
#                 "audio_url": "https://ipanel.instream.audio:7001/stream",
#                 "time_zone": "America/Buenos_Aires",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/2a/a6/2aa6eb59-2455-4f33-9c88-a0c7055bd71c.jpg",
#                 "freq": "1070.00",
#                 "listen_mode": "ondemand+live",
#                 "band": "AM",
#                 "city": {
#                     "code": "BUE",
#                     "state": {
#                         "code": "AR-C",
#                         "country": {
#                             "code": "AR",
#                             "name": "Argentina"
#                         },
#                         "name": "Ciudad Aut\u00f3noma de Buenos Aires"
#                     },
#                     "name": "Ciudad de Buenos Aires"
#                 },
#                 "station_type": "r",
#                 "visibility": "p",
#                 "description_text": "Toda la informacion del Destape en Am"
#             }
#         },
#         {
#             "type": "RadioStation",
#             "value": {
#                 "slug": "capital-br",
#                 "name": "Capital 1040 AM",
#                 "webpage": "https://www.capitalcomvoce.com.br/",
#                 "audio_url": "https://ice.fabricahost.com.br/capitalfmsp",
#                 "time_zone": "America/Sao_Paulo",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/e2/04/e204ce42-8127-4381-9f38-44fbfea6252a.jpg",
#                 "freq": "1040.00",
#                 "listen_mode": "ondemand+live",
#                 "band": "AM",
#                 "city": {
#                     "code": "SAO",
#                     "state": {
#                         "code": "BR-SP",
#                         "country": {
#                             "code": "BR",
#                             "name": "Brasil"
#                         },
#                         "name": "S\u00e3o Paulo"
#                     },
#                     "name": "S\u00e3o Paulo"
#                 },
#                 "station_type": "r",
#                 "visibility": "p",
#                 "description_text": ""
#             }
#         }
#     ]
# }

# %% [markdown]
# #### Búsqueda de un término solo en recortes

# %%
import requests
import json

url = 'https://radiocut.fm/api/search/?type=cut&search_term=avion'
headers = {
    'Authorization': 'Token ${api_token}'
}
response = requests.get(url)
json_data = response.json()

print(json.dumps(json_data, indent=4, ensure_ascii=False))
# Out:
# {
#     "count": 2148,
#     "next": "https://radiocut.fm/api/search/?page=2&search_term=avion&type=cut",
#     "previous": null,
#     "results": [
#         {
#             "type": "AudioCut",
#             "value": {
#                 "episode": null,
#                 "description": "Avión estrellado en rosario",
#                 "title": "Accidente avioneta",
#                 "radio_obj": {
#                     "slug": "rosario2",
#                     "name": "Radio 2",
#                     "webpage": "http://www.rosario3.com/",
#                     "audio_url": "http://radio2.radio.rosario3.com:8000/prueba2",
#                     "time_zone": "America/Buenos_Aires",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/e3/f6/e3f62861-b5e6-4a21-9b6a-896f92bbb87e.png",
#                     "freq": "1230.00",
#                     "listen_mode": "ondemand+live",
#                     "band": "AM",
#                     "city": {
#                         "code": "ROS",
#                         "state": {
#                             "code": "AR-S",
#                             "country": {
#                                 "code": "AR",
#                                 "name": "Argentina"
#                             },
#                             "name": "Santa Fe"
#                         },
#                         "name": "Rosario"
#                     },
#                     "station_type": "r",
#                     "visibility": "p",
#                     "description_text": ""
#                 },
#                 "tags": [
#                     {
#                         "title": "avión estrellado rosario",
#                         "slug": "avion-estrellado-rosario",
#                         "id": 610559
#                     }
#                 ],
#                 "show": "panorama-1",
#                 "show_obj": {
#                     "slug": "panorama-1",
#                     "name": "El Contestador ",
#                     "description": "Con la conducción de Pablo Motto ",
#                     "radio": "rosario2",
#                     "twitter": "",
#                     "facebook": "",
#                     "webpage": "",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/shows_logos/f7/98/f7981528-49ec-4a7d-82d3-ae05d4331e26.jpg",
#                     "radio_obj": {
#                         "slug": "rosario2",
#                         "name": "Radio 2",
#                         "webpage": "http://www.rosario3.com/",
#                         "audio_url": "http://radio2.radio.rosario3.com:8000/prueba2",
#                         "time_zone": "America/Buenos_Aires",
#                         "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/e3/f6/e3f62861-b5e6-4a21-9b6a-896f92bbb87e.png",
#                         "freq": "1230.00",
#                         "listen_mode": "ondemand+live",
#                         "band": "AM",
#                         "city": {
#                             "code": "ROS",
#                             "state": {
#                                 "code": "AR-S",
#                                 "country": {
#                                     "code": "AR",
#                                     "name": "Argentina"
#                                 },
#                                 "name": "Santa Fe"
#                             },
#                             "name": "Rosario"
#                         },
#                         "station_type": "r",
#                         "visibility": "p",
#                         "description_text": ""
#                     },
#                     "visibility": "p"
#                 },
#                 "visibility": "p",
#                 "created": "2024-08-09T22:39:46.544Z",
#                 "play_count": 6,
#                 "start": "2024-08-09T16:37:24.575000+00:00",
#                 "length": 115,
#                 "radio": "rosario2",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/shows_logos/f7/98/f7981528-49ec-4a7d-82d3-ae05d4331e26.jpg",
#                 "owner": {
#                     "username": "Walterhaiek69",
#                     "id": 325877
#                 },
#                 "pk": 2078766,
#                 "slug": "accidente-avioneta"
#             }
#         },
#         {
#             "type": "AudioCut",
#             "value": {
#                 "episode": null,
#                 "description": "Seguimos conociendo los detalles sobre los vuelos de la muerte ocurridos en Campo de Mayo. De la mano de La Retaguardia y su cobertura para el El Diario del Juicio.\r\nEn este caso otro testimonio de un excolimba aportó un dato revelador: un oceanógrafo iba a Campo de Mayo para charlar con los pilotos de los aviones que realizaban los Vuelos de la Muerte para coordinar cuando y donde se arrojaban los cuerpos de las víctimas del terrorismo de Estado. \r\nFernando Tebele, comunicador popular de La Retaguardia nos contó al respecto.\r\n",
#                 "title": "VUELOS DE LA MUERTE: UN OCEANÓGRAFO GUIABA A MILITARES SOBRE DONDE ARROJAR LOS CUERPOS DE VÍCTIMAS",
#                 "radio_obj": {
#                     "slug": "fm-la-uni-917",
#                     "name": "FM La Uni 91.7",
#                     "webpage": "http://www.ungs.edu.ar/fmlauni/",
#                     "audio_url": "https://cdn.instream.audio/:9275/stream",
#                     "time_zone": "America/Buenos_Aires",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/11741083_680700665407272_5467690102052263619_o.jpg",
#                     "freq": "91.70",
#                     "listen_mode": "ondemand+live",
#                     "band": "FM",
#                     "city": {
#                         "code": "PBA",
#                         "state": {
#                             "code": "AR-B",
#                             "country": {
#                                 "code": "AR",
#                                 "name": "Argentina"
#                             },
#                             "name": "Buenos Aires"
#                         },
#                         "name": "Provincia Buenos Aires"
#                     },
#                     "station_type": "r",
#                     "visibility": "p",
#                     "description_text": ""
#                 },
#                 "tags": [
#                     {
#                         "title": "campo de mayo",
#                         "slug": "campo-mayo",
#                         "id": 238000
#                     },
#                     {
#                         "title": "dictadura militar argentina",
#                         "slug": "dictadura-militar-argentina",
#                         "id": 316126
#                     },
#                     {
#                         "title": "juicios",
#                         "slug": "juicios",
#                         "id": 2373
#                     },
#                     {
#                         "title": "la retaguardia",
#                         "slug": "retaguardia",
#                         "id": 237146
#                     },
#                     {
#                         "title": "vuelos de la muerte",
#                         "slug": "vuelos-muerte",
#                         "id": 255532
#                     }
#                 ],
#                 "show": "para-manana-es-tarde",
#                 "show_obj": {
#                     "slug": "para-manana-es-tarde",
#                     "name": "Para Mañana Es Tarde",
#                     "description": "",
#                     "radio": "fm-la-uni-917",
#                     "twitter": "",
#                     "facebook": "",
#                     "webpage": "",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/11741083_680700665407272_5467690102052263619_o.jpg",
#                     "radio_obj": {
#                         "slug": "fm-la-uni-917",
#                         "name": "FM La Uni 91.7",
#                         "webpage": "http://www.ungs.edu.ar/fmlauni/",
#                         "audio_url": "https://cdn.instream.audio/:9275/stream",
#                         "time_zone": "America/Buenos_Aires",
#                         "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/11741083_680700665407272_5467690102052263619_o.jpg",
#                         "freq": "91.70",
#                         "listen_mode": "ondemand+live",
#                         "band": "FM",
#                         "city": {
#                             "code": "PBA",
#                             "state": {
#                                 "code": "AR-B",
#                                 "country": {
#                                     "code": "AR",
#                                     "name": "Argentina"
#                                 },
#                                 "name": "Buenos Aires"
#                             },
#                             "name": "Provincia Buenos Aires"
#                         },
#                         "station_type": "r",
#                         "visibility": "p",
#                         "description_text": ""
#                     },
#                     "visibility": "p"
#                 },
#                 "visibility": "p",
#                 "created": "2021-03-10T14:23:00.287Z",
#                 "play_count": 13,
#                 "start": "2021-03-10T13:42:36+00:00",
#                 "length": 911,
#                 "radio": "fm-la-uni-917",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/cuts_logos/80/25/802513cf-7e6c-47cf-ac96-6461480ad2f2.jpg",
#                 "owner": {
#                     "username": "LaUniFM91.7",
#                     "id": 13396
#                 },
#                 "pk": 1267624,
#                 "slug": "vuelos-muerte-un-oceanografo-guiaba-a-militares-sobre-donde-arrojar-cuerpos-victimas-1"
#             }
#         },
#         {
#             "type": "AudioCut",
#             "value": {
#                 "episode": null,
#                 "description": "Estados Unidos y Rusia concretaron el mayor intercambio internacional de prisioneros desde la Guerra Fría. Después de días y semanas de intensas transacciones en la mayor confidencialidad, siete aviones aterrizaron el jueves en el aeropuerto de Ankara. En total 26 pasajeros, ya sea reclamados por Rusia o por Occidente. ¿Por qué se produjo ahora este intercambio de prisioneros, donde participaron tantos países y Turquia?\r\n",
#                 "title": "Iván Ivanov, experto de Rusia, de la OTAN y prof. de Cs. Políticas de la U. de Cincinnati",
#                 "radio_obj": {
#                     "slug": "ciudad",
#                     "name": "La Once Diez",
#                     "webpage": "http://www.buenosaires.gob.ar/radiociudad",
#                     "audio_url": "https://media.radios.ar:1110",
#                     "time_zone": "America/Buenos_Aires",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/2d/bb/2dbbcb74-3b2d-4b01-9c90-9776f48e7d70.jpg",
#                     "freq": "1110.00",
#                     "listen_mode": "ondemand+live",
#                     "band": "AM",
#                     "city": {
#                         "code": "BUE",
#                         "state": {
#                             "code": "AR-C",
#                             "country": {
#                                 "code": "AR",
#                                 "name": "Argentina"
#                             },
#                             "name": "Ciudad Autónoma de Buenos Aires"
#                         },
#                         "name": "Ciudad de Buenos Aires"
#                     },
#                     "station_type": "r",
#                     "visibility": "p",
#                     "description_text": ""
#                 },
#                 "tags": [],
#                 "show": "corresponsales-en-linea",
#                 "show_obj": {
#                     "slug": "corresponsales-en-linea",
#                     "name": "CORRESPONSALES EN LÍNEA",
#                     "description": "Siete periodistas pensando el Mundo.\r\nTodos los temas que involucran a nuestro país con el mundo estarán presentes en Corresponsales en línea: política internacional, economía, sociedad, tendencias, deportes, ciencia, cultura y espectáculos.\r\n\r\nLas corresponsales en línea son: Silvia Naishtat (Buenos Aires), Sofía Neiman (Buenos Aires), Paula Lugones (Washington), Danielle Raymond (París), María Laura Avignolo (París), Silvia Pisani (Washington) y Cristina Veiga (San Pablo).\r\n\r\n \r\nProducción ejecutiva: María Eugenia Plano",
#                     "radio": "ciudad",
#                     "twitter": "",
#                     "facebook": "",
#                     "webpage": "https://www.buenosaires.gob.ar/medios/radio-ciudad-am-1110",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/shows_logos/13/a4/13a4e63f-4a12-467e-9168-45b192432e22.png",
#                     "radio_obj": {
#                         "slug": "ciudad",
#                         "name": "La Once Diez",
#                         "webpage": "http://www.buenosaires.gob.ar/radiociudad",
#                         "audio_url": "https://media.radios.ar:1110",
#                         "time_zone": "America/Buenos_Aires",
#                         "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/2d/bb/2dbbcb74-3b2d-4b01-9c90-9776f48e7d70.jpg",
#                         "freq": "1110.00",
#                         "listen_mode": "ondemand+live",
#                         "band": "AM",
#                         "city": {
#                             "code": "BUE",
#                             "state": {
#                                 "code": "AR-C",
#                                 "country": {
#                                     "code": "AR",
#                                     "name": "Argentina"
#                                 },
#                                 "name": "Ciudad Autónoma de Buenos Aires"
#                             },
#                             "name": "Ciudad de Buenos Aires"
#                         },
#                         "station_type": "r",
#                         "visibility": "p",
#                         "description_text": ""
#                     },
#                     "visibility": "p"
#                 },
#                 "visibility": "p",
#                 "created": "2024-08-04T14:47:26.224Z",
#                 "play_count": 17,
#                 "start": "2024-08-04T14:30:28+00:00",
#                 "length": 901,
#                 "radio": "ciudad",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/shows_logos/13/a4/13a4e63f-4a12-467e-9168-45b192432e22.png",
#                 "owner": {
#                     "username": "corresponsalesenlinea",
#                     "id": 139509
#                 },
#                 "pk": 2076712,
#                 "slug": "ivan-ivanov-experto-rusia-otan-y-prof-cs-politicas-u-cincinnati"
#             }
#         },
#         {
#             "type": "AudioCut",
#             "value": {
#                 "episode": null,
#                 "description": "\"Más Que Medio Lleno\".\r\nMilei pudo pavonearse entre los jefes de Estado del G-7, en el mejor fin de semana de su gobierno, aunque la crónica del New York Times sobre el encuentro frente al Mar Adriático no menciona al libertario argentino entre los invitados de élite de la primera ministra italiana Giorgia Meloni: Narendra Modi, Lula, Erdogan, Mohammed bin Zayed,  Zelenski y Jorge Bergoglio. Después el Presidente voló a Suiza para reunirse con su colega, el standupero ucraniano Zelenski, a quien la Argentina decidió entregar cinco aviones franceses adquiridos por Macrì, que nunca volaron porque Londres impidió que se hicieran de piezas británicas vitales para su funcionamiento en condiciones de combate.\r\nEl editorial de Horacio Verbitsky del 16/06/2024 en El Cohete a la Luna.",
#                 "title": "Horacio Verbitsky - Más Que Medio Lleno - El Cohete a la Luna",
#                 "radio_obj": {
#                     "slug": "madres",
#                     "name": "AM 530 - Somos Radio",
#                     "webpage": "https://am530somosradio.com/",
#                     "audio_url": "https://ipanel.instream.audio:7000/stream",
#                     "time_zone": "America/Buenos_Aires",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/9d/af/9daffd2f-b4dc-4e1e-8242-ee98a4e66ae9.jpg",
#                     "freq": "530.00",
#                     "listen_mode": "ondemand+live",
#                     "band": "AM",
#                     "city": {
#                         "code": "BUE",
#                         "state": {
#                             "code": "AR-C",
#                             "country": {
#                                 "code": "AR",
#                                 "name": "Argentina"
#                             },
#                             "name": "Ciudad Autónoma de Buenos Aires"
#                         },
#                         "name": "Ciudad de Buenos Aires"
#                     },
#                     "station_type": "r",
#                     "visibility": "p",
#                     "description_text": ""
#                 },
#                 "tags": [
#                     {
#                         "title": "am 530",
#                         "slug": "am-530",
#                         "id": 4395
#                     },
#                     {
#                         "title": "am 530 somos radio",
#                         "slug": "am-530-somos-radio",
#                         "id": 177050
#                     },
#                     {
#                         "title": "el cohete a la luna",
#                         "slug": "cohete-a-luna_1",
#                         "id": 262033
#                     },
#                     {
#                         "title": "horacio verbitsky",
#                         "slug": "horacio-verbitsky",
#                         "id": 1184
#                     },
#                     {
#                         "title": "somos radio",
#                         "slug": "somos-radio",
#                         "id": 171128
#                     }
#                 ],
#                 "show": "cohete-a-luna",
#                 "show_obj": {
#                     "slug": "cohete-a-luna",
#                     "name": "El cohete a la Luna",
#                     "description": "",
#                     "radio": "madres",
#                     "twitter": "",
#                     "facebook": "",
#                     "webpage": "",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/9d/af/9daffd2f-b4dc-4e1e-8242-ee98a4e66ae9.jpg",
#                     "radio_obj": {
#                         "slug": "madres",
#                         "name": "AM 530 - Somos Radio",
#                         "webpage": "https://am530somosradio.com/",
#                         "audio_url": "https://ipanel.instream.audio:7000/stream",
#                         "time_zone": "America/Buenos_Aires",
#                         "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/9d/af/9daffd2f-b4dc-4e1e-8242-ee98a4e66ae9.jpg",
#                         "freq": "530.00",
#                         "listen_mode": "ondemand+live",
#                         "band": "AM",
#                         "city": {
#                             "code": "BUE",
#                             "state": {
#                                 "code": "AR-C",
#                                 "country": {
#                                     "code": "AR",
#                                     "name": "Argentina"
#                                 },
#                                 "name": "Ciudad Autónoma de Buenos Aires"
#                             },
#                             "name": "Ciudad de Buenos Aires"
#                         },
#                         "station_type": "r",
#                         "visibility": "p",
#                         "description_text": ""
#                     },
#                     "visibility": "p"
#                 },
#                 "visibility": "p",
#                 "created": "2024-06-16T13:34:46.047Z",
#                 "play_count": 712,
#                 "start": "2024-06-16T12:06:52+00:00",
#                 "length": 4144,
#                 "radio": "madres",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/cuts_logos/be/9f/be9ff798-716c-4e82-b2d3-3276abb15984.png",
#                 "owner": {
#                     "username": "somosradio",
#                     "id": 144544
#                 },
#                 "pk": 2061658,
#                 "slug": "horacio-verbitsky-mas-medio-lleno-cohete-a-luna"
#             }
#         },
#         {
#             "type": "AudioCut",
#             "value": {
#                 "episode": null,
#                 "description": "Santiago Torre Walsh, \"Sir Chandler\", creador de un blog de un viajero frecuente, visitó el piso de La Mañana de CNN para conversar con Nacho Girón y equipo. Habló sobre cómo comenzó su proyecto, su larga experiencia en aviones y reveló algunos consejos a la hora de viajar.",
#                 "title": "SANTIAGO TORRE WALSH \"Sir Chandler\" en La Mañana de CNN",
#                 "radio_obj": {
#                     "slug": "cnn-argentina",
#                     "name": "CNN Radio AM 950",
#                     "webpage": "http://www.cnnradio.com.ar/",
#                     "audio_url": "https://unlimited2-ar.dps.live/cnn-ar/aac/icecast.audio",
#                     "time_zone": "America/Buenos_Aires",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/61/d7/61d7454a-58d1-450d-8068-e41f759fd82b.jpg",
#                     "freq": "950.00",
#                     "listen_mode": "ondemand+live",
#                     "band": "AM",
#                     "city": {
#                         "code": "BUE",
#                         "state": {
#                             "code": "AR-C",
#                             "country": {
#                                 "code": "AR",
#                                 "name": "Argentina"
#                             },
#                             "name": "Ciudad Autónoma de Buenos Aires"
#                         },
#                         "name": "Ciudad de Buenos Aires"
#                     },
#                     "station_type": "r",
#                     "visibility": "p",
#                     "description_text": ""
#                 },
#                 "tags": [
#                     {
#                         "title": "sir chandler",
#                         "slug": "sir-chandler",
#                         "id": 25814
#                     },
#                     {
#                         "title": "sir chandler blog",
#                         "slug": "sir-chandler-blog",
#                         "id": 25815
#                     }
#                 ],
#                 "show": "cafe-con-pepe",
#                 "show_obj": {
#                     "slug": "cafe-con-pepe",
#                     "name": "La Mañana de CNN - Nacho Girón",
#                     "description": "Columnistas: Virginia Porcella (Economía), Jaime Rosemberg (Política), Guido Bercovich (Deportes), Maite Peñoñori (Cultura y Espectaculos). Locución: Romina Aldana. María Patricia Fiorentino (Tránsito y servicios). Móvil: Nicolás Gallardo.",
#                     "radio": "cnn-argentina",
#                     "twitter": "cnnradioarg",
#                     "facebook": "cnnradioargentina",
#                     "webpage": "http://www.cnnradio.com.ar/",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/61/d7/61d7454a-58d1-450d-8068-e41f759fd82b.jpg",
#                     "radio_obj": {
#                         "slug": "cnn-argentina",
#                         "name": "CNN Radio AM 950",
#                         "webpage": "http://www.cnnradio.com.ar/",
#                         "audio_url": "https://unlimited2-ar.dps.live/cnn-ar/aac/icecast.audio",
#                         "time_zone": "America/Buenos_Aires",
#                         "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/61/d7/61d7454a-58d1-450d-8068-e41f759fd82b.jpg",
#                         "freq": "950.00",
#                         "listen_mode": "ondemand+live",
#                         "band": "AM",
#                         "city": {
#                             "code": "BUE",
#                             "state": {
#                                 "code": "AR-C",
#                                 "country": {
#                                     "code": "AR",
#                                     "name": "Argentina"
#                                 },
#                                 "name": "Ciudad Autónoma de Buenos Aires"
#                             },
#                             "name": "Ciudad de Buenos Aires"
#                         },
#                         "station_type": "r",
#                         "visibility": "p",
#                         "description_text": ""
#                     },
#                     "visibility": "p"
#                 },
#                 "visibility": "p",
#                 "created": "2023-06-29T16:08:01.155Z",
#                 "play_count": 277,
#                 "start": "2023-06-29T15:37:13+00:00",
#                 "length": 1142,
#                 "radio": "cnn-argentina",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/61/d7/61d7454a-58d1-450d-8068-e41f759fd82b.jpg",
#                 "owner": {
#                     "username": "nachogiron",
#                     "id": 42830
#                 },
#                 "pk": 1911963,
#                 "slug": "santiago-torre-walsh-sir-chandler-en-manana-cnn"
#             }
#         },
#         {
#             "type": "AudioCut",
#             "value": {
#                 "episode": null,
#                 "description": "2024-04-06+18.34HS // segunda parte del programa DIALOGO INTERNACIONAL, difundiendo la realidad latinoamericana y entre temas, TRATADOS de ECUADOR convirtiendo al pais, cuasi una base EEUU integral  /// se DESTACA LA ENTREVISTA  a MATIAS CASIAGUE,, entendido de la UNDEF y temas geopolíticos, ALARMANDO con su mirada periodística de la visita de la GENERALA del COMANDO SUR / EEUU y el CIPAYO DE MILEI ENTREGANDO UN FUTURO PUERTO en USUAHIA,,,,,entre desplazar a los \" PAISES MALIGNOS de china, irán, etc\", REPUDIANDO LA BASE CHINA en NEUQUEN,y reafirmando con la capacidad militar diplomática de la generala, de una AGENDA GRINGA,,,,,,MILITARIZANDO LAS AGENDAS DIPLOMÁTICAS DE LATINOAMERICA desde los EEUU, y bendiciendo el material OCCIDENTAL de compras de aviones obsoletos, los 24 AVIONES  F 16 a DINAMARCA, que esta cambiando su flota y siempre hay VENDE PATRIAS comprando obsolescencias programadas /// NO NOS OLVIDEMOS DE LA HIDRO VIA Y EEUU, no es CHINA, /// y el puerto regalado por MILEI \" puñal\" A LA SOBERANIA NACIONAL, controlando, malvinas, paso de océanos, puente antártico, en definitiva un puerto IMPERIAL de EEUU, contra el mercosur, o la presencia y control de china, /// la entrevista es ENRIQUECEDORA y te abre la cabeza de los TEMAS CASTRENSES y lo que no sabemos del dia, por no ser nuestro metie,,,,!!! ////",
#                 "title": "MILEI BUFON PAPELON y DISCURSO VIAJE USHUAIA + programa DIALOGO INTERNACIONAL - AM 530 + PARTE DOS",
#                 "radio_obj": {
#                     "slug": "madres",
#                     "name": "AM 530 - Somos Radio",
#                     "webpage": "https://am530somosradio.com/",
#                     "audio_url": "https://ipanel.instream.audio:7000/stream",
#                     "time_zone": "America/Buenos_Aires",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/9d/af/9daffd2f-b4dc-4e1e-8242-ee98a4e66ae9.jpg",
#                     "freq": "530.00",
#                     "listen_mode": "ondemand+live",
#                     "band": "AM",
#                     "city": {
#                         "code": "BUE",
#                         "state": {
#                             "code": "AR-C",
#                             "country": {
#                                 "code": "AR",
#                                 "name": "Argentina"
#                             },
#                             "name": "Ciudad Autónoma de Buenos Aires"
#                         },
#                         "name": "Ciudad de Buenos Aires"
#                     },
#                     "station_type": "r",
#                     "visibility": "p",
#                     "description_text": ""
#                 },
#                 "tags": [
#                     {
#                         "title": "am 530 somos radio",
#                         "slug": "am-530-somos-radio",
#                         "id": 177050
#                     },
#                     {
#                         "title": "arq claudio antonio rozas avalos",
#                         "slug": "arq-claudio-antonio-rozas-avalos",
#                         "id": 529246
#                     },
#                     {
#                         "title": "atilio borón",
#                         "slug": "atilio-boron",
#                         "id": 1387
#                     },
#                     {
#                         "title": "base puerto militar ushuaia",
#                         "slug": "base-puerto-militar-ushuaia",
#                         "id": 600578
#                     },
#                     {
#                         "title": "dialogo internacional",
#                         "slug": "dialogo-internacional_1",
#                         "id": 494794
#                     },
#                     {
#                         "title": "hidrovia parana",
#                         "slug": "hidrovia-parana_1",
#                         "id": 391156
#                     },
#                     {
#                         "title": "la radio de las madres de plaza de mayo",
#                         "slug": "radio-madres-plaza-mayo_2",
#                         "id": 600576
#                     },
#                     {
#                         "title": "matias casiague",
#                         "slug": "matias-casiague",
#                         "id": 600577
#                     },
#                     {
#                         "title": "paula klachko",
#                         "slug": "paula-klachko",
#                         "id": 124745
#                     },
#                     {
#                         "title": "telma luzzani",
#                         "slug": "telma-luzzani",
#                         "id": 1742
#                     }
#                 ],
#                 "show": "dialogo-internacional",
#                 "show_obj": {
#                     "slug": "dialogo-internacional",
#                     "name": "Diálogo internacional",
#                     "description": "Política internacional con Atilio Borón, Federico Montero y Telma Luzzani.",
#                     "radio": "madres",
#                     "twitter": "",
#                     "facebook": "",
#                     "webpage": "",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/shows_logos/9a/c9/9ac985be-e015-440e-95e0-6f998c6e6867.jpg",
#                     "radio_obj": {
#                         "slug": "madres",
#                         "name": "AM 530 - Somos Radio",
#                         "webpage": "https://am530somosradio.com/",
#                         "audio_url": "https://ipanel.instream.audio:7000/stream",
#                         "time_zone": "America/Buenos_Aires",
#                         "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/9d/af/9daffd2f-b4dc-4e1e-8242-ee98a4e66ae9.jpg",
#                         "freq": "530.00",
#                         "listen_mode": "ondemand+live",
#                         "band": "AM",
#                         "city": {
#                             "code": "BUE",
#                             "state": {
#                                 "code": "AR-C",
#                                 "country": {
#                                     "code": "AR",
#                                     "name": "Argentina"
#                                 },
#                                 "name": "Ciudad Autónoma de Buenos Aires"
#                             },
#                             "name": "Ciudad de Buenos Aires"
#                         },
#                         "station_type": "r",
#                         "visibility": "p",
#                         "description_text": ""
#                     },
#                     "visibility": "p"
#                 },
#                 "visibility": "p",
#                 "created": "2024-04-07T04:21:23.086Z",
#                 "play_count": 15,
#                 "start": "2024-04-06T21:34:42+00:00",
#                 "length": 1765,
#                 "radio": "madres",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/shows_logos/9a/c9/9ac985be-e015-440e-95e0-6f998c6e6867.jpg",
#                 "owner": {
#                     "username": "CLAUDIOANTONIOROZASAVALOS",
#                     "id": 312668
#                 },
#                 "pk": 2035247,
#                 "slug": "milei-bufon-papelon-y-discurso-viaje-ushuaia-programa-dialogo-internacional-am-530-parte-dos"
#             }
#         },
#         {
#             "type": "AudioCut",
#             "value": {
#                 "episode": null,
#                 "description": "Es un trastorno de ansiedad. Lo sufren chicos que son incapaces de hablar en ciertas situaciones sociales, como en el ámbito escolar. En Modo Avión, Pablo Sigal y Mario Esman dialogaron con Fabiana Baracchini, experta en el tema, quien contó cómo identificar el problema y qué se puede hacer para tratarlo.",
#                 "title": "“El mutismo selectivo se puede tratar”",
#                 "radio_obj": {
#                     "slug": "concepto",
#                     "name": "Concepto",
#                     "webpage": "http://www.conceptofm.com.ar/",
#                     "audio_url": "http://radios.solumedia.com:6002/stream",
#                     "time_zone": "America/Buenos_Aires",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/concepto.png",
#                     "freq": "95.50",
#                     "listen_mode": "ondemand+live",
#                     "band": "FM",
#                     "city": {
#                         "code": "BUE",
#                         "state": {
#                             "code": "AR-C",
#                             "country": {
#                                 "code": "AR",
#                                 "name": "Argentina"
#                             },
#                             "name": "Ciudad Autónoma de Buenos Aires"
#                         },
#                         "name": "Ciudad de Buenos Aires"
#                     },
#                     "station_type": "r",
#                     "visibility": "p",
#                     "description_text": ""
#                 },
#                 "tags": [
#                     {
#                         "title": "centro mutismo selectivo internacional",
#                         "slug": "centro-mutismo-selectivo-internacional",
#                         "id": 290669
#                     },
#                     {
#                         "title": "fabiana baracchini",
#                         "slug": "fabiana-baracchini",
#                         "id": 290506
#                     },
#                     {
#                         "title": "mario esman",
#                         "slug": "mario-esman",
#                         "id": 139759
#                     },
#                     {
#                         "title": "modo avión",
#                         "slug": "modo-avion_1",
#                         "id": 99163
#                     },
#                     {
#                         "title": "mutismo selectivo",
#                         "slug": "mutismo-selectivo",
#                         "id": 290507
#                     },
#                     {
#                         "title": "orientación a padres",
#                         "slug": "orientacion-a-padres",
#                         "id": 290665
#                     },
#                     {
#                         "title": "pablo sigal",
#                         "slug": "pablo-sigal",
#                         "id": 99164
#                     },
#                     {
#                         "title": "psicoterapia infantil",
#                         "slug": "psicoterapia-infantil",
#                         "id": 290666
#                     },
#                     {
#                         "title": "terapia cognitivo conductual",
#                         "slug": "terapia-cognitivo-conductual",
#                         "id": 290664
#                     },
#                     {
#                         "title": "trastorno de ansiedad",
#                         "slug": "trastorno-ansiedad",
#                         "id": 254738
#                     }
#                 ],
#                 "show": "modo-avion_5",
#                 "show_obj": {
#                     "slug": "modo-avion_5",
#                     "name": "MODO AVION",
#                     "description": "“Modo Avión” propone una hora de noticias, reflexión, entrevistas y debate sobre educación, salud, ciencia, tecnología, tendencias, consumo, sustentabilidad y medioambiente. Un espacio para desconectarnos del vértigo político, que invita a poner la lupa sobre otras cuestiones clave de la sociedad que merecen atención. Un recorrido por la coyuntura y el análisis de los aspectos más sensibles y destacables de estas áreas temáticas. Conduce Pablo Sigal, junto a Mario Esman.",
#                     "radio": "concepto",
#                     "twitter": "",
#                     "facebook": "puradataweb",
#                     "webpage": "",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/shows_logos/a3/f0/a3f07155-065e-4160-85a1-f40b7a304ed6.jpg",
#                     "radio_obj": {
#                         "slug": "concepto",
#                         "name": "Concepto",
#                         "webpage": "http://www.conceptofm.com.ar/",
#                         "audio_url": "http://radios.solumedia.com:6002/stream",
#                         "time_zone": "America/Buenos_Aires",
#                         "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/concepto.png",
#                         "freq": "95.50",
#                         "listen_mode": "ondemand+live",
#                         "band": "FM",
#                         "city": {
#                             "code": "BUE",
#                             "state": {
#                                 "code": "AR-C",
#                                 "country": {
#                                     "code": "AR",
#                                     "name": "Argentina"
#                                 },
#                                 "name": "Ciudad Autónoma de Buenos Aires"
#                             },
#                             "name": "Ciudad de Buenos Aires"
#                         },
#                         "station_type": "r",
#                         "visibility": "p",
#                         "description_text": ""
#                     },
#                     "visibility": "p"
#                 },
#                 "visibility": "p",
#                 "created": "2019-11-01T11:33:59.746Z",
#                 "play_count": 87,
#                 "start": "2019-11-01T00:23:23+00:00",
#                 "length": 1024,
#                 "radio": "concepto",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/shows_logos/a3/f0/a3f07155-065e-4160-85a1-f40b7a304ed6.jpg",
#                 "owner": {
#                     "username": "PuraDATA",
#                     "id": 85180
#                 },
#                 "pk": 893800,
#                 "slug": "entrevista-a-fabiana-baracchini"
#             }
#         },
#         {
#             "type": "AudioCut",
#             "value": {
#                 "episode": null,
#                 "description": "Cinco generaciones: Aviones de la Paternal a el Palomar, expropiación, abandono, transferencia a la municipalidad de la ciudad, ocupado como vivienda y sin agua ni cloacas. Ocupación y creación de una \"micro ciudad\" por la carencia de programas de viviendas populares. Juicio al estado de los Etchebarne  y en 1991 implosión del edificio.Símbolo de un  destino de un país. Juan Etchebarne y su participación en las torturas de Campo de Mayo. Entre el odio y los negociados con violencia hacia lo popular. ¿Será de la misma familia?",
#                 "title": "El linaje de la Familia Etchebarne.Dueños de los terrenos del Albergue Warnes,17 hectáreas símbólica",
#                 "radio_obj": {
#                     "slug": "madres",
#                     "name": "AM 530 - Somos Radio",
#                     "webpage": "https://am530somosradio.com/",
#                     "audio_url": "https://ipanel.instream.audio:7000/stream",
#                     "time_zone": "America/Buenos_Aires",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/9d/af/9daffd2f-b4dc-4e1e-8242-ee98a4e66ae9.jpg",
#                     "freq": "530.00",
#                     "listen_mode": "ondemand+live",
#                     "band": "AM",
#                     "city": {
#                         "code": "BUE",
#                         "state": {
#                             "code": "AR-C",
#                             "country": {
#                                 "code": "AR",
#                                 "name": "Argentina"
#                             },
#                             "name": "Ciudad Autónoma de Buenos Aires"
#                         },
#                         "name": "Ciudad de Buenos Aires"
#                     },
#                     "station_type": "r",
#                     "visibility": "p",
#                     "description_text": ""
#                 },
#                 "tags": [
#                     {
#                         "title": "historia de la ciudad",
#                         "slug": "historia-ciudad",
#                         "id": 330575
#                     },
#                     {
#                         "title": "negocios y torturas",
#                         "slug": "negocios-y-torturas",
#                         "id": 330576
#                     },
#                     {
#                         "title": "ocupación ilegal",
#                         "slug": "ocupacion-ilegal",
#                         "id": 115581
#                     }
#                 ],
#                 "show": "siempre-es-hoy-1",
#                 "show_obj": {
#                     "slug": "siempre-es-hoy-1",
#                     "name": "Siempre es hoy",
#                     "description": "Magazine periodístico de la mañana, transitando su décima temporada. Conducido por Daniel Tognetti. Lo acompañan Rulo Dellatorre, Eduardo Fabregat, Sergio Wischñesky, Juan Luis González y Valentina Castro.\r\n",
#                     "radio": "madres",
#                     "twitter": "somosradioam530",
#                     "facebook": "somosradioam530",
#                     "webpage": "",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/shows_logos/e2/6d/e26d4a75-37c8-446a-8f57-93d63ee2fbca.jpg",
#                     "radio_obj": {
#                         "slug": "madres",
#                         "name": "AM 530 - Somos Radio",
#                         "webpage": "https://am530somosradio.com/",
#                         "audio_url": "https://ipanel.instream.audio:7000/stream",
#                         "time_zone": "America/Buenos_Aires",
#                         "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/9d/af/9daffd2f-b4dc-4e1e-8242-ee98a4e66ae9.jpg",
#                         "freq": "530.00",
#                         "listen_mode": "ondemand+live",
#                         "band": "AM",
#                         "city": {
#                             "code": "BUE",
#                             "state": {
#                                 "code": "AR-C",
#                                 "country": {
#                                     "code": "AR",
#                                     "name": "Argentina"
#                                 },
#                                 "name": "Ciudad Autónoma de Buenos Aires"
#                             },
#                             "name": "Ciudad de Buenos Aires"
#                         },
#                         "station_type": "r",
#                         "visibility": "p",
#                         "description_text": ""
#                     },
#                     "visibility": "p"
#                 },
#                 "visibility": "p",
#                 "created": "2020-05-23T18:18:19.964Z",
#                 "play_count": 114,
#                 "start": "2020-05-22T14:44:07+00:00",
#                 "length": 646,
#                 "radio": "madres",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/cuts_logos/b5/5f/b55f953c-10c7-49f3-97e1-d57de8a0b89b.jpg",
#                 "owner": {
#                     "username": "AdrianaCab",
#                     "id": 9181
#                 },
#                 "pk": 1026988,
#                 "slug": "linaje-familia-etchebarne-duenos-terrenos-del-albergue-warnes-17-hectareas-simbolica"
#             }
#         },
#         {
#             "type": "AudioCut",
#             "value": {
#                 "episode": null,
#                 "description": "El ufólogo explica sus hipótesis sobre la desaparición de la nave malaya. ",
#                 "title": "Fabio Zerpa habla en Gente Sexy sobre el avión desaparecido ",
#                 "radio_obj": {
#                     "slug": "rockandpop",
#                     "name": "FM Rock & Pop",
#                     "webpage": "http://www.fmrockandpop.com/",
#                     "audio_url": "https://playerservices.streamtheworld.com/api/livestream-redirect/ROCKANDPOPAAC.aac",
#                     "time_zone": "America/Buenos_Aires",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/a4/60/a460888b-a89c-4873-81dc-3c5aae8defbf.jpg",
#                     "freq": "95.90",
#                     "listen_mode": "ondemand+live",
#                     "band": "FM",
#                     "city": {
#                         "code": "BUE",
#                         "state": {
#                             "code": "AR-C",
#                             "country": {
#                                 "code": "AR",
#                                 "name": "Argentina"
#                             },
#                             "name": "Ciudad Autónoma de Buenos Aires"
#                         },
#                         "name": "Ciudad de Buenos Aires"
#                     },
#                     "station_type": "r",
#                     "visibility": "p",
#                     "description_text": ""
#                 },
#                 "tags": [
#                     {
#                         "title": "clemente cancela",
#                         "slug": "clemente-cancela",
#                         "id": 4632
#                     },
#                     {
#                         "title": "gente sexy",
#                         "slug": "gente-sexy",
#                         "id": 4633
#                     },
#                     {
#                         "title": "santiago calori",
#                         "slug": "santiago-calori",
#                         "id": 5021
#                     },
#                     {
#                         "title": "sebastián de caro",
#                         "slug": "sebastian-de-caro",
#                         "id": 1631
#                     }
#                 ],
#                 "show": "gentesexy",
#                 "show_obj": {
#                     "slug": "gentesexy",
#                     "name": "Gente Sexy",
#                     "description": "Con Clemente Cancela (@clementedeviaje), Joe Fernández (@joefernandezok) y Santiago Calori (@sancalori)",
#                     "radio": "rockandpop",
#                     "twitter": "GenteSexy_959",
#                     "facebook": "",
#                     "webpage": "",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/shows_logos/IMG-20150827-WA0083.jpg",
#                     "radio_obj": {
#                         "slug": "rockandpop",
#                         "name": "FM Rock & Pop",
#                         "webpage": "http://www.fmrockandpop.com/",
#                         "audio_url": "https://playerservices.streamtheworld.com/api/livestream-redirect/ROCKANDPOPAAC.aac",
#                         "time_zone": "America/Buenos_Aires",
#                         "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/a4/60/a460888b-a89c-4873-81dc-3c5aae8defbf.jpg",
#                         "freq": "95.90",
#                         "listen_mode": "ondemand+live",
#                         "band": "FM",
#                         "city": {
#                             "code": "BUE",
#                             "state": {
#                                 "code": "AR-C",
#                                 "country": {
#                                     "code": "AR",
#                                     "name": "Argentina"
#                                 },
#                                 "name": "Ciudad Autónoma de Buenos Aires"
#                             },
#                             "name": "Ciudad de Buenos Aires"
#                         },
#                         "station_type": "r",
#                         "visibility": "p",
#                         "description_text": ""
#                     },
#                     "visibility": "p"
#                 },
#                 "visibility": "p",
#                 "created": "2014-03-21T23:20:22.806Z",
#                 "play_count": 560,
#                 "start": "2014-03-19T12:50:33+00:00",
#                 "length": 1080,
#                 "radio": "rockandpop",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/shows_logos/IMG-20150827-WA0083.jpg",
#                 "owner": {
#                     "username": "NedStark",
#                     "id": 900
#                 },
#                 "pk": 7616,
#                 "slug": "fabio-zerpa-habla-en-gente-sexy-sobre-el-avion-desaparecido"
#             }
#         },
#         {
#             "type": "AudioCut",
#             "value": {
#                 "episode": null,
#                 "description": "Dialogamos con la secretaria de Turismo de El Calafate, Julieta Saita, quien nos habla sobre la actividad turística de la región en época invernal y el Programa \"El Calafate Invita\". En este sentido, nos cuenta sobre las visitas que recibió la localidad y qué actividades de invierno ofrece El Calafate, así como también capacidad hotelera y gastronómica. Por otro lado, hablamos sobre cómo afecta la crisis económica al turismo en la provincia y el aumento en los pasajes de colectivo y avión. ",
#                 "title": "#EntrevistaLU14 - Julieta Saita",
#                 "radio_obj": {
#                     "slug": "lu14-provincia-de-santa-cruz",
#                     "name": "LU14",
#                     "webpage": "http://www.lu14.com.ar/",
#                     "audio_url": "https://transmision-lu14.santacruz.gob.ar/lu14.mp3",
#                     "time_zone": "America/Buenos_Aires",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/logo_lu14.png",
#                     "freq": "830.00",
#                     "listen_mode": "ondemand+live",
#                     "band": "AM",
#                     "city": {
#                         "code": "RGA",
#                         "state": {
#                             "code": "AR-Z",
#                             "country": {
#                                 "code": "AR",
#                                 "name": "Argentina"
#                             },
#                             "name": "Santa Cruz"
#                         },
#                         "name": "Río Gallegos"
#                     },
#                     "station_type": "r",
#                     "visibility": "p",
#                     "description_text": ""
#                 },
#                 "tags": [],
#                 "show": "uno-por-uno",
#                 "show_obj": {
#                     "slug": "uno-por-uno",
#                     "name": "Uno por uno",
#                     "description": "Toda la información en la segunda mañana. Entrevistas e información con el sello del experimentado Walter Muñoz. ",
#                     "radio": "lu14-provincia-de-santa-cruz",
#                     "twitter": "",
#                     "facebook": "",
#                     "webpage": "",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/shows_logos/f0/6f/f06f5556-88bf-4520-9c22-e63c8b32176f.jpg",
#                     "radio_obj": {
#                         "slug": "lu14-provincia-de-santa-cruz",
#                         "name": "LU14",
#                         "webpage": "http://www.lu14.com.ar/",
#                         "audio_url": "https://transmision-lu14.santacruz.gob.ar/lu14.mp3",
#                         "time_zone": "America/Buenos_Aires",
#                         "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/logo_lu14.png",
#                         "freq": "830.00",
#                         "listen_mode": "ondemand+live",
#                         "band": "AM",
#                         "city": {
#                             "code": "RGA",
#                             "state": {
#                                 "code": "AR-Z",
#                                 "country": {
#                                     "code": "AR",
#                                     "name": "Argentina"
#                                 },
#                                 "name": "Santa Cruz"
#                             },
#                             "name": "Río Gallegos"
#                         },
#                         "station_type": "r",
#                         "visibility": "p",
#                         "description_text": ""
#                     },
#                     "visibility": "p"
#                 },
#                 "visibility": "p",
#                 "created": "2024-07-29T16:30:03.649Z",
#                 "play_count": 5,
#                 "start": "2024-07-29T14:37:15+00:00",
#                 "length": 816,
#                 "radio": "lu14-provincia-de-santa-cruz",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/shows_logos/f0/6f/f06f5556-88bf-4520-9c22-e63c8b32176f.jpg",
#                 "owner": {
#                     "username": "almadediamante",
#                     "id": 430
#                 },
#                 "pk": 2074774,
#                 "slug": "entrevistalu14-julieta-saita-2"
#             }
#         },
#         {
#             "type": "AudioCut",
#             "value": {
#                 "episode": null,
#                 "description": "¿Cómo afecta el cambio climático a las turbulencias en los aviones? ",
#                 "title": "Podría ser Peor -  Fonti con Daniel Lampert, Piloto",
#                 "radio_obj": {
#                     "slug": "rosario2",
#                     "name": "Radio 2",
#                     "webpage": "http://www.rosario3.com/",
#                     "audio_url": "http://radio2.radio.rosario3.com:8000/prueba2",
#                     "time_zone": "America/Buenos_Aires",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/e3/f6/e3f62861-b5e6-4a21-9b6a-896f92bbb87e.png",
#                     "freq": "1230.00",
#                     "listen_mode": "ondemand+live",
#                     "band": "AM",
#                     "city": {
#                         "code": "ROS",
#                         "state": {
#                             "code": "AR-S",
#                             "country": {
#                                 "code": "AR",
#                                 "name": "Argentina"
#                             },
#                             "name": "Santa Fe"
#                         },
#                         "name": "Rosario"
#                     },
#                     "station_type": "r",
#                     "visibility": "p",
#                     "description_text": ""
#                 },
#                 "tags": [],
#                 "show": "podria-ser-peor-1",
#                 "show_obj": {
#                     "slug": "podria-ser-peor-1",
#                     "name": "Podría Ser Peor ",
#                     "description": "Con la conducción de Juan Manuel Fontana ",
#                     "radio": "rosario2",
#                     "twitter": "",
#                     "facebook": "",
#                     "webpage": "",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/shows_logos/f2/65/f265652c-f0e0-41c3-9bee-a72e9651d0ef.jpg",
#                     "radio_obj": {
#                         "slug": "rosario2",
#                         "name": "Radio 2",
#                         "webpage": "http://www.rosario3.com/",
#                         "audio_url": "http://radio2.radio.rosario3.com:8000/prueba2",
#                         "time_zone": "America/Buenos_Aires",
#                         "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/e3/f6/e3f62861-b5e6-4a21-9b6a-896f92bbb87e.png",
#                         "freq": "1230.00",
#                         "listen_mode": "ondemand+live",
#                         "band": "AM",
#                         "city": {
#                             "code": "ROS",
#                             "state": {
#                                 "code": "AR-S",
#                                 "country": {
#                                     "code": "AR",
#                                     "name": "Argentina"
#                                 },
#                                 "name": "Santa Fe"
#                             },
#                             "name": "Rosario"
#                         },
#                         "station_type": "r",
#                         "visibility": "p",
#                         "description_text": ""
#                     },
#                     "visibility": "p"
#                 },
#                 "visibility": "p",
#                 "created": "2024-07-19T20:20:25.364Z",
#                 "play_count": 16,
#                 "start": "2024-07-17T22:15:53+00:00",
#                 "length": 488,
#                 "radio": "rosario2",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/shows_logos/f2/65/f265652c-f0e0-41c3-9bee-a72e9651d0ef.jpg",
#                 "owner": {
#                     "username": "marianojunco",
#                     "id": 345066
#                 },
#                 "pk": 2071997,
#                 "slug": "podria-ser-peor-fonti-con-daniel-lampert-piloto"
#             }
#         },
#         {
#             "type": "AudioCut",
#             "value": {
#                 "episode": null,
#                 "description": "Mónica, PILOTO DE AVIÓN....nos habló de la maravillosa experiencia de VOLAR.",
#                 "title": "En Reporte Rivadavia, conversamos con Monica Martus.",
#                 "radio_obj": {
#                     "slug": "rivadavia",
#                     "name": "Rivadavia",
#                     "webpage": "http://www.rivadavia.com.ar/",
#                     "audio_url": "https://playerservices.streamtheworld.com/pls/RIVADAVIAAAC.pls",
#                     "time_zone": "America/Buenos_Aires",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/77/93/7793b356-44fe-4e77-a360-8b95dc9fc943.jpg",
#                     "freq": "630.00",
#                     "listen_mode": "ondemand+live",
#                     "band": "AM",
#                     "city": {
#                         "code": "BUE",
#                         "state": {
#                             "code": "AR-C",
#                             "country": {
#                                 "code": "AR",
#                                 "name": "Argentina"
#                             },
#                             "name": "Ciudad Autónoma de Buenos Aires"
#                         },
#                         "name": "Ciudad de Buenos Aires"
#                     },
#                     "station_type": "r",
#                     "visibility": "p",
#                     "description_text": ""
#                 },
#                 "tags": [],
#                 "show": "reporte-rivadavia-4",
#                 "show_obj": {
#                     "slug": "reporte-rivadavia-4",
#                     "name": "REPORTE RIVADAVIA",
#                     "description": "",
#                     "radio": "rivadavia",
#                     "twitter": "",
#                     "facebook": "",
#                     "webpage": "https://www.rivadavia.com.ar/",
#                     "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/shows_logos/e7/e8/e7e8db35-14f1-45ee-881f-7f452f02a052.jpg",
#                     "radio_obj": {
#                         "slug": "rivadavia",
#                         "name": "Rivadavia",
#                         "webpage": "http://www.rivadavia.com.ar/",
#                         "audio_url": "https://playerservices.streamtheworld.com/pls/RIVADAVIAAAC.pls",
#                         "time_zone": "America/Buenos_Aires",
#                         "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/radio_logos/77/93/7793b356-44fe-4e77-a360-8b95dc9fc943.jpg",
#                         "freq": "630.00",
#                         "listen_mode": "ondemand+live",
#                         "band": "AM",
#                         "city": {
#                             "code": "BUE",
#                             "state": {
#                                 "code": "AR-C",
#                                 "country": {
#                                     "code": "AR",
#                                     "name": "Argentina"
#                                 },
#                                 "name": "Ciudad Autónoma de Buenos Aires"
#                             },
#                             "name": "Ciudad de Buenos Aires"
#                         },
#                         "station_type": "r",
#                         "visibility": "p",
#                         "description_text": ""
#                     },
#                     "visibility": "p"
#                 },
#                 "visibility": "p",
#                 "created": "2021-12-21T11:16:50.057Z",
#                 "play_count": 93,
#                 "start": "2021-12-19T05:11:06.036000+00:00",
#                 "length": 1064,
#                 "radio": "rivadavia",
#                 "logo": "https://imgsvr.radiocut.site/get/crop/center/200/200/cuts_logos/a9/ed/a9ed8a3b-e4f2-4708-8201-91ab8c5be68e.jpg",
#                 "owner": {
#                     "username": "oscar2",
#                     "id": 9543
#                 },
#                 "pk": 1516983,
#                 "slug": "en-reporte-rivadavia-conversamos-con-monica-martus"
#             }
#         }
#     ]
# }

# %% [markdown]
# #### Búsqueda de un término en una radio y creado en los últimos 7 días.

# %%
import requests
import json

url = 'https://radiocut.fm/api/search/?type=cut&search_term=avion&radio=am750&created=7'
headers = {
    'Authorization': 'Token ${api_token}'
}
response = requests.get(url)
json_data = response.json()

print(json.dumps(json_data, indent=4, ensure_ascii=False))
# Out:
# {
#     "count": 0,
#     "next": null,
#     "previous": null,
#     "results": []
# }
